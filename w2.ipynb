# %%
#W2a1:
print('Hello World')
# Out:
# Hello World

# %%
#w2a2
a=input('Tên bạn là gì?')
print('Ồ, chào '+a)
# Out:
# Tên bạn là gì? Minh
# Ồ, chào Minh

# %%
#w2a3
a = int(input('nhập số nguyên a='))
b = int(input('nhập số nguyên b='))
print('Tổng: ', a+b)
print('Hiệu a-b: ', a-b)
print('Tích: ', a*b)
print('Phần nguyên của a chia b:', a//b)
print('Phần dư của a chia b: ', a%b)
print('a chia b (làm tròn đến chữ số thập phân thứ 2): ', round(a/b, 2))
# Out:
# nhập số nguyên a= 9
# nhập số nguyên b= 7
# Tổng:  16
# Hiệu a-b:  2
# Tích:  63
# Phần nguyên của a chia b: 1
# Phần dư của a chia b:  2
# a chia b (làm tròn đến chữ số thập phân thứ 2):  1.29

# %%
#w2a4
a1, b1, c1, a2, b2, a3=map(float,input('Nhập lần lượt các điểm a1 b1 c1 a2 b2 a3 theo đúng thứ tự và cách nhau bằng dấu cách: ').split())
a=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print('Điểm trung bình của bạn là: ', a)
# Out:
# Nhập lần lượt các điểm a1 b1 c1 a2 b2 a3 theo đúng thứ tự và cách nhau bằng dấu cách:  7 8 8 7 9 9
# Điểm trung bình của bạn là:  8.2

# %%
#w2a5
a, b=map(int,input('Nhập hai số nguyên a và b cách nhau 1 dấu cách: ').split())
print('Kết quả a mũ b: ', a**b)
# Out:
# Nhập hai số nguyên a và b cách nhau 1 dấu cách:  3 2
# Kết quả a mũ b:  9

# %%
#w2a6
x=input('Nhập vào một chữ cái thường từ a->z: ')
if ord('a') <= ord(x) <=ord('z'):
    print('Kí tự in hoa tương ứng là: ', chr(ord(x)-32))
else:
    print('Vui lòng nhập lại một chữ cái thường từ a->z!')
# Out:
# Nhập vào một chữ cái thường từ a->z:  f
# Kí tự in hoa tương ứng là:  F

# %%
#w2a7
A=((13**2)*3)+5
B=13**2*3+5
print('A= ', A, '; B= ', B)
# Out:
# A=  512 ; B=  512

# %%
#w2a8
C=float(input('Nhập số độ C mà bạn muốn chuyển sang độ F: '))
F=9/5*C+32
print('Số độ F tương ứng: ', F)
# Out:
# Nhập số độ C mà bạn muốn chuyển sang độ F:  15
# Số độ F tương ứng:  59.0

# %%
#w2a9
x=float(input('Nhập giá gốc đồng hồ Movado: '))
print('Số tiền thực tế phải trả khi mua là: ', 10+14/10*x)
# Out:
# Nhập giá gốc đồng hồ Movado:  67
# Số tiền thực tế phải trả khi mua là:  103.8

# %%
#w2a10
a,b,c=input('Nhập tên 3 bạn trên 1 dòng và cách nhau bằng một dấu cách: ').split(maxsplit=2)
print('Tên 3 bạn theo thứ tự ngược lại là: ', c,',', b, 'and', a)
# Out:
# Nhập tên 3 bạn trên 1 dòng và cách nhau bằng một dấu cách:  Mạnh Dũng Hùng
# Tên 3 bạn theo thứ tự ngược lại là:  Hùng , Dũng and Mạnh

# %%
#w2a11
a=int(input('Nhập số giờ: '))
b=int(input("Nhập số phút: "))
print('số giờ và phút được chuyển sang đơn vị giây: ', a*3600+b*60)
# Out:
# Nhập số giờ:  1
# Nhập số phút:  3
# số giờ và phút được chuyển sang đơn vị giây:  3780

# %%
#w2a12
n=int(input('Nhập độ dài cạnh của khối rubik: '))
print('Số miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương là: ', n*n*6)
# Out:
# Nhập độ dài cạnh của khối rubik:  1
# Số miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương là:  6

# %%
#w2a13
a=int(input('Nhập số nguyên dương a: '))
b=int(input('Nhập số nguyên dương b: '))
if a>0 and b>0:
    print('Kết quả của phép tính axb: ', a*b)
else: 
    print('Vui lòng nhập lại chính xác hai số nguyên dương a và b.')
# Out:
# Nhập số nguyên dương a:  -8
# Nhập số nguyên dương b:  5
# Vui lòng nhập lại chính xác hai số nguyên dương a và b.

# %%
#w2a14
a=float(input('Nhập a: '))
b=float(input('Nhập b: '))
a,b=b,a
print('Sau khi hoán đổi:\na= ',a, '\nb= ',b, sep='  ')
# Out:
# Nhập a:  1
# Nhập b:  2
# Sau khi hoán đổi:
# a=   2.0
# b=   1.0

# %%
#w2q15
def so_sao_thu_n(n):
    if n<1:
        raise VallueError('Vui lòng nhập lại số n phải là nguyên dương')
    return 6*n*(n-1)+1
n=int(input('Nhập số nguyên dương n: '))
print(f'Số sao thứ {n} là: {so_sao_thu_n(n)}')
# Out:
# Nhập số nguyên dương n:  3
# Số sao thứ 3 là: 37

# %%
#w2a16
print('spring\nsummer\nautumn\nwinter')
a=['spring','summer','autumn','winter']
for i in a:
    print(i)
# Out:
# spring
# summer
# autumn
# winter
# spring
# summer
# autumn
# winter

# %%
#w2a17
print('   *   ')
print('  ***  ')
print(' ***** ')
# Out:
#    *
#   ***
#  *****

# %%
#w2a18
print('### ##   ### ###')
print(' #  # #   #   # ')
print(' #  #  #  #   # ')
print(' #  #  #  #   # ')
print(' #  ##    #   # ')
# Out:
# ### ##   ### ###
#  #  # #   #   #
#  #  #  #  #   #
#  #  #  #  #   #
#  #  ##    #   #

# %%
#w2a19
a=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
for i in a:
    print(i)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#w2a20
a=['January','February','March','April','May','June','July','August','September']
for i in a:
    print(i)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September

# %%
#w2a21
for i in range(0,10):
    print('Hello, world')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
