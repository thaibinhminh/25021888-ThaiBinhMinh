# %%
#w1a1
a=7
b=5
c=a-b
print(c)
# Out:
# 2

# %%
#w1a2
city="Hà Nội"
year= 2025
print("Thành phố", city, "-năm", year)
# Out:
# Thành phố Hà Nội -năm 2025

# %%
#w1a3
n=4
t=0
for i in range(1,n+1):
    t+=i
print(t)
# Out:
# 10

# %%
#w1a4
numbers = [1, 2, 3, 4]
for x in numbers:
    if x % 2 == 0:
        print(x, "là số chẵn")
    else:
        print(x, "là số lẻ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %%
#w1a5
animals = ["cat", "dog", "cat", "bird"]
count = 0
for a in animals:
    count += 1

print("Số phần tử trong danh sách là:", count)
# Out:
# Số phần tử trong danh sách là: 4

# %%
#w1a6
print('=== AI Prediction System ===')
print('(1) Sentiment analysis')
print('(2) Weather forecast')
input('Please choose an option: ')
#Giải thích:
#Dòng === AI Prediction System === Đây là tiêu đề của chương trình. Cho biết chương trình này là một hệ thống dự đoán bằng AI.

#Dòng 1) Sentiment analysis. Là tùy chọn số 1 cho người dùng. Nếu chọn, chương trình sẽ thực hiện phân tích cảm xúc (sentiment analysis), ví dụ: xác định văn bản là tích cực, tiêu cực, hay trung lập.

#Dòng 2) Weather forecast. Là tùy chọn số 2 cho người dùng. Nếu chọn, chương trình sẽ đưa ra dự báo thời tiết.

#Dòng 3) Exit. Là tùy chọn số 3 cho người dùng. Nếu chọn, chương trình sẽ thoát.

#Dòng Please choose an option: Chương trình đang chờ nhập dữ liệu từ người dùng (input). Người dùng sẽ nhập 1, 2, hoặc 3.

#Sau đó chương trình mới chạy tiếp (ví dụ gọi hàm xử lý tương ứng).

#👉 Kết quả bạn thấy trên màn hình chỉ là menu của chương trình, chưa phải kết quả cuối cùng.
#Chương trình sẽ làm gì tiếp theo hoàn toàn phụ thuộc vào lựa chọn của người dùng.
# Out:
# === AI Prediction System ===
# (1) Sentiment analysis
# (2) Weather forecast
# Please choose an option:  2
# '2'

# %%
#w1a7
print('Lỗi 1: input() trả về chuỗi (string)')
print('Lỗi 2: Dấu so sánh trong if')
print('Lỗi 3: Thụt lề (indentation)')
num = int(input("Nhập số: "))

if num % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Lỗi 1: input() trả về chuỗi (string)
# Lỗi 2: Dấu so sánh trong if
# Lỗi 3: Thụt lề (indentation)
# Nhập số:  7
# Số lẻ

# %%
#w1a8
for i in range(3):
    print("AI đang học lần", i + 1)
    print("Huấn luyện xong!")
print('1. for i in range(3):')

print('range(3) tạo ra dãy số: 0, 1, 2. Vòng lặp sẽ chạy 3 lần với i lần lượt bằng 0, 1, 2.')
print('2. print(AI đang học lần, i + 1')
print('Vì i bắt đầu từ 0, nên i + 1 sẽ là 1, 2, 3. Mỗi lần lặp, dòng này in ra:')
print('AI đang học lần 1')
print('AI đang học lần 2')
print('AI đang học lần 3')
print('3.print("Huấn luyện xong!")')

print('Dòng này không thụt lề, nên nằm ngoài vòng lặp.Vì vậy, nó chỉ được in một lần duy nhất sau khi vòng lặp kết thúc.')
# Out:
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!
# 1. for i in range(3):
# range(3) tạo ra dãy số: 0, 1, 2. Vòng lặp sẽ chạy 3 lần với i lần lượt bằng 0, 1, 2.
# 2. print(AI đang học lần, i + 1
# Vì i bắt đầu từ 0, nên i + 1 sẽ là 1, 2, 3. Mỗi lần lặp, dòng này in ra:
# AI đang học lần 1
# AI đang học lần 2
# AI đang học lần 3
# 3.print("Huấn luyện xong!")
# Dòng này không thụt lề, nên nằm ngoài vòng lặp.Vì vậy, nó chỉ được in một lần duy nhất sau khi vòng lặp kết thúc.

# %%
#w1a9
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
#1. for x in ["cat", "dog", "fish"]:
#Đây là một vòng lặp for.
#Danh sách ["cat", "dog", "fish"] gồm 3 chuỗi (string).
#2. print("Dự đoán con vật:", x)
#Trong mỗi lần lặp, in ra chuỗi "Dự đoán con vật:" kèm theo giá trị hiện tại của x.
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %%
#w1a10
#print("2) Weather forecast"))   - Thừa 1 dấu ) 
#print('3) Exit'                 - Thiếu dấu )
# viết lại
# Simple menu
print("=== AI Prediction System ===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
input("Please choose an option:")
# Out:
# === AI Prediction System ===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option: 1
# '1'
